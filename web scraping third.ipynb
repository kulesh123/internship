# %% [markdown]
# 1. Write a python program which searches all the product under a particular product from www.amazon.in. The
# product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for
# guitars.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException

# %%
productname=[]

# %%
def search(input):
    driver=webdriver.Chrome()
    driver.get("https://www.amazon.in/")
    time.sleep(5)
    search=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
    search.send_keys(input)
    click=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
    click.click()
    
    product=driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')
    for i in product:
        if i.text is None:
            productname.append('-')
        else:
            productname.append(i.text)
    print(productname)

# %%
search("bluetooth")
# Out:
# ['pTron Bassbuds Air in-Ear TWS Earbuds with 13mm Driver for Immersive Sound, 32Hrs Playtime, Clear Calls, Bluetooth V5.1, Touch Control, TypeC Fast Charging, Voice Assist & IPX4 Water Resistant', 'Boult Audio Z20 Truly Wireless in Ear Earbuds with 51H Playtime, Zen™ Clear Calling ENC Mic, Made in India, Low Latency Gaming, Rich Bass Drivers, IPX5, Voice Assistant, Bluetooth 5.3 Ear Buds (Black)', 'boAt Rockerz 330 in-Ear Bluetooth Neckband with Upto 30 Hours Playtime, ASAP\x99 Charge, Signature Sound, Dual Pairing & IPX5 with Mic (Active Black)', 'Portronics Harmonics Z7 Bluetooth Wireless in Ear Earphones with Upto 40 Hours Playback, 10mm Dynamic Driver, Gaming Mode, High Bass, IPX4 Water and Sweat Resistant, Type C Fast Charging(Black)', 'boAt Rockerz 255 Pro+ Bluetooth in Ear Neckband with Upto 60 Hours Playback, ASAP Charge, IPX7, Dual Pairing and Bluetooth v5.2(Active Black)', 'boAt Airdopes 141 Bluetooth Truly Wireless in Ear Earbuds with 42H Playtime,Low Latency Mode for Gami
# ...

# %% [markdown]
# 2. In the above question, now scrape the following details of each product listed in first 3 pages of your search
# results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then
# scrape all the products available under that product name. Details to be scraped are: "Brand
# Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and
# “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
url=[]

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.amazon.in/')

# %%
start=0
end=3
for page in range(start,end+1):
    urls=driver.find_elements(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div[1]/div/span[1]/div[1]/div[3]/div/div/div/div/span/div/div/div/div[1]/div/div[2]/div/span/a/div')
    for i in urls:
        url.append(i.get_attribute('href'))

# %%
print(url)
# Out:
# [None, None, None, None]

# %% [markdown]
# 3. Write a python program to access the search bar and search button on images.google.com and scrape 10
# images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’

# %%
searchitem=[]

# %%
def images(input):
    driver=webdriver.Chrome()
    driver.get('https://www.google.com/')
    search=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/div/div/div/div[1]/div/div[2]/a')
    search.click()
    find=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea')
    find.send_keys(input)
    click1=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div/span')
    click1.click()
    images=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
    for image in images[0:10]:
        file=image.get_attribute('src')
        searchitem.append(file)
    print(searchitem)

# %%
images('cars')
# Out:
# ['data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
images('fruits')
# Out:
# ['data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
images('Machine Learning')
# Out:
# ['data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/png;base64,...', 'data:image/png;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base
# ...

# %%
images('Guitar')
# Out:
# ['data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/png;base64,...', 'data:image/png;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base64,...', 'data:image/jpeg;base
# ...

# %% [markdown]
# images('Cakes')

# %% [markdown]
# 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
import re

# %%
def lat_long(city):
    driver=webdriver.Chrome()
    driver.get('https://www.google.com/maps')
    search=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div[8]/div[3]/div[1]/div[1]/div/div[2]/form/input')
    search.send_keys(city)
    click=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div[8]/div[3]/div[1]/div[1]/div/div[2]/div[1]/button')
    click.click()
    time.sleep(3)
    url=driver.current_url
    lat_long=re.findall(r'@(.*),',url)
    print(lat_long)

# %%
lat_long("Bihar")
# Out:
# ['25.8799668,83.1641841']

# %% [markdown]
# 6. Write a program to scrap all the available details of best gaming laptops from digit.in

# %%
driver=webdriver.Chrome()
driver.get('https://www.digit.in/top-products/best-gaming-laptops-40.html')
brand=[]
brnd=driver.find_elements(By.XPATH,'//div[@class="rh_gr_top_middle mb10 colored_rate_bar"]')
for i in brnd:
    brand.append(str(i.text).replace("\n",""))
print(brand)
# Out:
# ['HP Omen 17-ck2008TX 13th Gen Core i7-13700HX', 'MSI GT77 Titan 12UHS-054IN 12th Gen Core i9-12900HX', 'Lenovo Legion 5i Pro 12th Gen Core i7-12700H (82RF00E1IN)', 'ASUS ROG Strix Scar 18 G834JZ-N5041WS 13th Gen Core i9-13980HX', 'Acer Predator Helios Neo 16 13th Gen Core i7-13700HX (PHN16-71)', 'ASUS ROG Zephyrus G14 Ryzen 9-6900HS (GA402RJZ-L4136WS)', 'MSI Cyborg 15 12th Gen Core i7-12650H (A12VF-205IN)']

# %%
brand
# Out:
# ['HP Omen 17-ck2008TX 13th Gen Core i7-13700HX',
#  'MSI GT77 Titan 12UHS-054IN 12th Gen Core i9-12900HX',
#  'Lenovo Legion 5i Pro 12th Gen Core i7-12700H (82RF00E1IN)',
#  'ASUS ROG Strix Scar 18 G834JZ-N5041WS 13th Gen Core i9-13980HX',
#  'Acer Predator Helios Neo 16 13th Gen Core i7-13700HX (PHN16-71)',
#  'ASUS ROG Zephyrus G14 Ryzen 9-6900HS (GA402RJZ-L4136WS)',
#  'MSI Cyborg 15 12th Gen Core i7-12650H (A12VF-205IN)']

# %%
specification=[]
spec=driver.find_elements(By.XPATH,'//div[@class="rh_gr_middle_desc"]')
for i in spec:
    name=i.text
    specification.append(name.replace("\n",""))
print(specification)
# Out:
# ['Operating System:Windows 11 HomeDisplay Size :17.3Resolution :2560 x 1440Processor :13th Gen Intel Core i7-13700HX', '', 'Operating System:Windows 11 HomeDisplay Size :16Resolution :2560 x 1600Processor :12th Gen Intel Core i7-12700H', '', 'Operating System:Windows 11 HomeDisplay Size :16Resolution :2560 x 1600Processor :13th Gen Intel Core i7-13700HX', '', '']

# %%
specification
# Out:
# ['Operating System:Windows 11 HomeDisplay Size :17.3Resolution :2560 x 1440Processor :13th Gen Intel Core i7-13700HX',
#  '',
#  'Operating System:Windows 11 HomeDisplay Size :16Resolution :2560 x 1600Processor :12th Gen Intel Core i7-12700H',
#  '',
#  'Operating System:Windows 11 HomeDisplay Size :16Resolution :2560 x 1600Processor :13th Gen Intel Core i7-13700HX',
#  '',
#  '']

# %%
price=[]
prc=driver.find_elements(By.XPATH,'//div[@class="cegg-price-row"]')
for i in prc[0:7]:
    tag=i.text
    price.append(tag.replace("\n",""))
print(price)
# Out:
# ['out of stock', 'out of stock', 'out of stock', 'out of stock', 'Rs. 159,990Rs. 164,999in stock', 'out of stock', 'Rs. 118,300Rs. 145,000in stock']

# %%
import pandas as pd

# %%
df=pd.DataFrame({"Brand Name":brand,"Specification":specification,"Price":price})

# %%
df
# Out:
#                                           Brand Name  \
# 0       HP Omen 17-ck2008TX 13th Gen Core i7-13700HX
# 1  MSI GT77 Titan 12UHS-054IN 12th Gen Core i9-12...
# 2  Lenovo Legion 5i Pro 12th Gen Core i7-12700H (...
# 3  ASUS ROG Strix Scar 18 G834JZ-N5041WS 13th Gen...
# 4  Acer Predator Helios Neo 16 13th Gen Core i7-1...
# 5  ASUS ROG Zephyrus G14 Ryzen 9-6900HS (GA402RJZ...
# 6  MSI Cyborg 15 12th Gen Core i7-12650H (A12VF-2...
#
#                                        Specification  \
# 0  Operating System:Windows 11 HomeDisplay Size :...
# 1
# 2  Operating System:Windows 11 HomeDisplay Size :...
# 3
# 4  Operating System:Windows 11 HomeDisplay Size :...
# 5
# 6
#
#                             Price
# 0                    out of stock
# 1                    out of stock
# 2                    out of stock
# 3                    out of stock
# 4  Rs. 159,990Rs. 164,999in stock
# 5                    out of stock
# 6  Rs. 118,300Rs. 145,000in stock

# %% [markdown]
# Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted
# from any YouTube Video

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.youtube.com/")

# %%
def video(input):
    
    driver=webdriver.Chrome()
    driver.get("https://www.youtube.com/")
    
    
    search=driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/div/ytd-masthead/div[4]/div[2]/ytd-searchbox/form/div[1]/div[1]/input')
    search.send_keys(input)
    time.sleep(3)
            
        
        
        
    click=driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/div/ytd-masthead/div[4]/div[2]/ytd-searchbox/button/yt-icon/yt-icon-shape/icon-shape/div')
    click.click()
    try:
        firstclick=driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-search/div[1]/ytd-two-column-search-results-renderer/div/ytd-section-list-renderer/div[2]/ytd-item-section-renderer/div[3]/ytd-video-renderer[1]/div[1]/div/div[1]/div')
        firstclick.click()
    except NoSuchElementException as e:
        firstclick=driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-search/div[1]/ytd-two-column-search-results-renderer/div/ytd-section-list-renderer/div[2]/ytd-item-section-renderer/div[3]/ytd-video-renderer[1]/div[1]/ytd-thumbnail/a/yt-image/img')
        firstclick.click()
    scroll_pause_time = 2
    scrolls = 10
    for _ in range(scrolls):
        driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
        time.sleep(3)
        
        comments=driver.find_elements(By.XPATH,'//yt-formatted-string[@id="content-text"]')
        for i in comments[0:500]:
            
            name=i.text
            comment.append(name)
            upvote=driver.find_elements(By.XPATH,'//span[@id="vote-count-middle"]')
        
        
        
        for i in upvote[0:500]:
        
            new=i.text
            upvotes.append(new)
        tm=driver.find_elements(By.XPATH,'//yt-formatted-string[@class="published-time-text style-scope ytd-comment-renderer"]')
        for i in tm[0:500]:
            tim=i.text
            times.append(tim)

# %%
scroll_pause_time = 2
scrolls = 10



for _ in range(scrolls):
  driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
  time.sleep(3)

# %%
comment=[]
upvotes=[]
times=[]

# %%
comments=driver.find_elements(By.XPATH,'//yt-formatted-string[@id="content-text"]')
for i in comments[0:500]:
    name=i.text
    comment.append(name)

# %%
comment
# Out:
# ["They're Tied In Blood & They Won't Stop!",
#  'Bobby deol deserved more time in this movie,,, His every scene was superb',
#  '2:31 this tone an another level ',
#  'The main thing in this whole scene is the chemistry between ranbir and bobby. The emotions they carry through out the fight without just uttering a single word .wow. Just getting goosbumps everytime i watch it .',
#  'Ranveer Kapoor is fire  but Bobby Deol is a atom bomb . Song + Emotion + Action = Goosebumps Song',
#  '2:38 what a stare by bobby ',
#  "I can't tell what was the experience when this song played in theatre truly masterpiece goosebumps on each beat ..B praak nailed it ",
#  '1:03 Abrar saying to Vijay "C\'mon bro I am ready for you" . Superb direction and acting from Bobby',
#  '0:41 Takiya ganji wala punch..',
#  'Bobby deol deserves best villain award this year.',
# ...

# %%
upvote=driver.find_elements(By.XPATH,'//span[@id="vote-count-middle"]')
for i in upvote[0:500]:
    new=i.text
    upvotes.append(new)

# %%
upvotes
# Out:
# ['3.8K',
#  '151',
#  '606',
#  '298',
#  '73',
#  '305',
#  '341',
#  '233',
#  '11',
#  '615',
#  '15',
#  '317',
#  '829',
#  '82',
#  '506',
#  '9',
#  '124',
#  '91',
#  '54',
#  '29',
#  '111',
#  '9',
#  '201',
#  '59',
#  '12',
#  '273',
#  '94',
#  '24',
#  '27',
#  '127',
#  '76',
#  '14',
#  '82',
#  '5',
#  '50',
#  '110',
#  '179',
#  '2',
#  '157',
#  '2',
#  '98',
#  '37',
#  '87',
#  '28',
#  '137',
#  '3',
#  '25',
#  '36',
#  '49',
#  '11',
#  '84',
#  '25',
#  '29',
#  '51',
#  '227',
#  '21',
#  '85',
#  '5',
#  '3.4K',
#  '99',
#  '97',
#  '1',
#  '38',
#  '3',
#  '58',
#  '84',
#  '122',
#  '7',
#  '95',
#  '2',
#  '21',
#  '27',
#  '20',
#  '',
#  '25',
#  '2',
#  '63',
#  '35',
#  '99',
#  '',
#  '1',
#  '135',
#  '9',
#  '54',
#  '1',
#  '5',
#  '2',
#  '17',
#  '26',
#  '7',
#  '',
#  '30',
#  '3',
#  '223',
#  '66',
#  '56',
#  '2',
#  '27',
#  '3',
#  '19',
#  '255',
#  '10',
#  '1',
#  '11',
#  '',
#  '20',
#  '14',
#  '1',
#  '34',
#  '1',
#  '89',
# ...

# %%
len(upvotes)
# Out:
# 140

# %%
tm=driver.find_elements(By.XPATH,'//yt-formatted-string[@class="published-time-text style-scope ytd-comment-renderer"]')
for i in tm[0:500]:
    tim=i.text
    times.append(tim)

# %%
len(times)
# Out:
# 360

# %% [markdown]
# 7. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped:
# “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
driver=webdriver.Chrome()

# %%
Name=[]

# %%
driver.get('https://www.forbes.com/billionaires/')

# %%
body=driver.find_element(By.XPATH,'')

# %% [markdown]
# Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in
# “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall
# reviews, privates from price, dorms from price, facilities and property description.

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.hostelworld.com/")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/input')
search.send_keys('London')

# %%
click=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div[2]/div/ul/li[2]/button')
click.click()

# %%
final=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[5]/button[1]')
final.click()

# %%
name=[]
distance=[]
rating=[]
review=[]
overallrvw=[]
privates=[]
dorms=[]
facilitypro=[]

# %%
body=driver.find_elements(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[1]/div/div/div[4]')
for i in body:
    
    try:
        
        names=driver.find_elements(By.XPATH,'//div[@class="property-name"]/span')
        
        for i in names:
            
            new=i.text
            name.append(new)
                
    except:
        print(name)
    try:
        distances=driver.find_elements(By.XPATH,'//span[@class="distance-description"]')
        for i in distances:
            dis=i.text
            distance.append(dis)
            
    except:
        print(distance)
            
            
    try:
        ratings=driver.find_elements(By.XPATH,'//span[@class="number"]')
        for i in ratings:
            rat=i.text
            rating.append(rat)
            
    except:
        print(rating)
            
    try:
        reviews=driver.find_elements(By.XPATH,'//div[@class="review"]')
        for i in reviews[3:33]:
            rev=i.text
            review.append(rev)
            
    except:
        print(review)
        
    try:
        over=driver.find_elements(By.XPATH,'//span[@class="keyword"]')
        for i in over[3:33]:
            ovr=i.text
            overallrvw.append(ovr)
    except:
        print(overallrvw)
        
    try:
        private=driver.find_elements(By.XPATH,'')

# %%
len(name)
# Out:
# 60

# %%
distances=driver.find_elements(By.XPATH,'//span[@class="distance-description"]')
for i in distances:
    dis=i.text
    distance.append(dis)

# %%
len(distance)
# Out:
# 30

# %%
ratings=driver.find_elements(By.XPATH,'')

# %%
len(review)
# Out:
# 30

# %%
Ratg=[]

# %%
body=driver.find_elements(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[1]/div/div/div[4]')
for i in body:
    
    rating=driver.find_elements(By.XPATH,'//span[@class="number"]')
    for i in rating[3:33]:
        
        rat=i.text
        Ratg.append(rat)

# %%
len(Ratg)
# Out:
# 30

# %%
Ratg
# Out:
# ['9.1',
#  '8.8',
#  '7.8',
#  '8.9',
#  '9.5',
#  '9.6',
#  '7.5',
#  '9.6',
#  '8.2',
#  '7.2',
#  '8.3',
#  '7.7',
#  '7.2',
#  '7.9',
#  '7.6',
#  '7.0',
#  '7.8',
#  '9.1',
#  '7.5',
#  '8.8',
#  '8.5',
#  '8.2',
#  '8.1',
#  '8.6',
#  '7.6',
#  '7.2',
#  '6.3',
#  '7.3',
#  '7.5',
#  '8.1']

# %%
ram=[]

# %%
import re

# %%
find=driver.find_elements(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[1]/div/div/div[4]/div[1]/a/a/div[2]/div[4]/div/div[1]/div[3]')
for price[1] in find:
    try:
        price=driver.find_elements(By.XPATH,'//strong["data-v-774cba8c"][@class="current"]')
        for i in price:
            if search==re.search("privates",price):
                new=i.text
                ram.append(new)
    except:
        print(raman)
# Out:
# []

# %%
ram
# Out:
# []

# %% [markdown]
# 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com
# and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand
# Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the
# details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
Brand=[]
smartphone=[]
color=[]
ram=[]
storage=[]
primarycam=[]
secondarycam=[]
dispaysize=[]
batterycpcty=[]
price=[]
producturl=[]
processor=[]
warrnty=[]

# %%
def smartphone(inputs):
    driver=webdriver.Chrome()
    driver.get("https://www.flipkart.com/")
    search=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/div[1]/header/div[1]/div[2]/form/div/div/input')
    search.send_keys(inputs)
    button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/div[1]/header/div[1]/div[2]/form/div/button')
    button.click()
    time.sleep(5)
    
    
    brand=driver.find_elements(By.XPATH,'//div[@class="_4rR01T"]')
    for i in brand:
        if i.text is None:
            Brand.append("--")
        else:
            Brand.append(i.text)
    
    rom=driver.find_elements(By.XPATH,'//ul[@class="_1xgFaf"]/li[1]')
    for i in rom:
        if i.text is None:
            storage.append("--")
        else:
            storage.append(i.text)
            
    display=driver.find_elements(By.XPATH,'//ul[@class="_1xgFaf"]/li[2]')
    for i in display:
        if i.text is None:
            dispaysize.append("--")
        else:
            dispaysize.append(i.text)
            
    primary=driver.find_elements(By.XPATH,'//ul[@class="_1xgFaf"]/li[3]')
    for i in primary:
        if i.text is None:
            primarycam.append("--")
        else:
            primarycam.append(i.text)
            
    proc=driver.find_elements(By.XPATH,'//ul[@class="_1xgFaf"]/li[4]')
    for i in proc:
        
        if i.text is None:
            processor.append("--")
        else:
            processor.append(i.text)
            
    wrnty=driver.find_elements(By.XPATH,'//ul[@class="_1xgFaf"]/li[5]')
    for i in wrnty:
        
        if i.text is None:
            warrnty.append("--")
        else:
            warrnty.append(i.text)
            
    prices=driver.find_elements(By.XPATH,'//div[@class="_30jeq3 _1_WHN1"]')
    for i in prices:
        if i.text is None:
            price.append("--")
            
        else:
            price.append(i.text)
            
            
    searchdetails=pd.DataFrame({"Brand name and colors":brand,"Secondary storage":storage,"Display size":dispaysize,"Primary Camera":primarycam,"Processor details":processor,"Warranty":warrnty,"Price":price})

# %% [markdown]
# In the above question, now scrape the following details of each product listed in first 3 pages of your search
# results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then
# scrape all the products available under that product name. Details to be scraped are: "Brand
# Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and
# “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“

# %%
def search(input):
    driver=webdriver.Chrome()
    driver.get("https://www.amazon.in/")
    time.sleep(5)
    search=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
    search.send_keys(input)
    click=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
    click.click()
    
    product=driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')
    for i in product:
        if i.text is None:
            productname.append('-')
        else:
            productname.append(i.text)
    print(productname)
